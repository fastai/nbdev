# %%
#|hide
 #| export

# %%
a = 'no directives'

# %% [markdown]
# some md

# %%
#|eval: false
assert 1 == 2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/jj/xl1rktcs6mn7ms6b8vvx8k4r0000gn/T/ipykernel_38804/2756147105.py in <module>
#       1 #|eval: false
# ----> 2 assert 1 == 2
#
# AssertionError:

# %%
#| notest
assert 1 == 2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/jj/xl1rktcs6mn7ms6b8vvx8k4r0000gn/T/ipykernel_38804/441260613.py in <module>
#       1 #| notest
# ----> 2 assert 1 == 2
#
# AssertionError:
